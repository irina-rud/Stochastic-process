# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import networkx

# %%
BeautifulSoup(urlopen('https://www.yandex.ru', timeout=10), 'lxml')
# Out:
# <!DOCTYPE html>
# ...

# %%
import numpy
# %matplotlib inline
edges = numpy.array([(2, 1), (2, 3), (3, 1)])
G=networkx.DiGraph()
G.add_edges_from(edges)
networkx.draw_circular(G, node_size=1000)
